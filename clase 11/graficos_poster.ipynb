# %%
import numpy as np
import nysg_tools as ny 
import pandas as pd
from math import log10
import pyvisa as visa
import matplotlib.pyplot as plt

# %%
#MISC: 

data1= pd.read_pickle('misc/data1')
data2= pd.read_pickle('misc/data2')
data3= pd.read_pickle('misc/data3')

# %%
normalized_data1 = (data1['VCH1'] - np.max(data1['VCH1']))*1000

# %%
np.std(data2['VCH1'])
# Out:
# 0.0735978695343822

# %%
data1
# Out:
#          time  VCH1  VCH2
# 0   -0.001281  19.2 -10.0
# 1   -0.001274  19.2 -10.0
# 2   -0.001268  19.2 -10.0
# 3   -0.001261  19.0 -10.0
# 4   -0.001255  19.2 -10.0
# ..        ...   ...   ...
# 995  0.005091  19.2   5.2
# 996  0.005097  19.2   5.6
# 997  0.005103  19.2   6.0
# 998  0.005110  19.2   6.4
# 999  0.005116  19.2   6.4
#
# [1000 rows x 3 columns]

# %%
for i in range(4):
    d1 = pd.read_pickle(f'cuadruple/silvia/v{i+1}')
    plt.plot(d1['time'],d1['VCH1'])
